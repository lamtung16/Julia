# %%
using Pkg
Pkg.add("Images")
Pkg.add("TestImages")
Pkg.add("ImageIO")
Pkg.add("QuartzImageIO")
Pkg.add("ImageMagick")
Pkg.add("ImageView")
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Resolving package versions...
#    Installed Images ──────────────────── v0.24.1
#    Installed AxisAlgorithms ──────────── v1.0.1
#    Installed OpenEXR ─────────────────── v0.3.2
#    Installed TensorCore ──────────────── v0.1.1
#    Installed ProgressMeter ───────────── v1.7.1
#    Installed PkgVersion ──────────────── v0.1.1
#    Installed Inflate ─────────────────── v0.1.2
#    Installed ColorVectorSpace ────────── v0.9.7
#    Installed TiffImages ──────────────── v0.5.2
#    Installed OpenEXR_jll ─────────────── v3.1.1+0
#    Installed FFTViews ────────────────── v0.3.2
#    Installed IfElse ──────────────────── v0.1.1
#    Installed Ratios ──────────────────── v0.4.2
#    Installed Netpbm ──────────────────── v1.0.1
#    Installed ArrayInterface ──────────── v3.1.40
#    Installed Parameters ──────────────── v0.12.3
#    Installed Rotations ───────────────── v1.0.4
#    Installed Imath_jll ───────────────── v3.1.2+0
#    Installed ImageIO ─────────────────── v0.5.9
#    Installed ImageShow ───────────────── v0.3.1
#    Installed EllipsisNotation ────────── v1.1.1
#    Installed TiledIteration ──────────── v0.3.1
#    Installed Static ──────────────────── v0.4.0
#    Installed ImageMagick ─────────────── v1.2.2
#    Installed PNGFiles ────────────────── v0.3.12
#    Installed WoodburyMatrices ────────── v0.5.5
#    Installed Graphics ────────────────── v1.1.1
#    Installed CoordinateTransformations ─ v0.6.2
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [916415d5] + Images v0.24.1
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [4fba245c] + ArrayInterface v3.1.40
#   [13072b0f] + AxisAlgorithms v1.0.1
#   [39de3d68] + AxisArrays v0.4.4
#   [fa961155] + CEnum v0.4.1
#   [aafaddc9] + CatIndices v0.2.2
#   [c3611d14] + ColorVectorSpace v0.9.7
#   [ed09eef8] + ComputationalResources v0.3.2
#   [150eb455] + CoordinateTransformations v0.6.2
#   [dc8bdbbb] + CustomUnitRanges v1.0.2
#   [da5c29d0] + EllipsisNotation v1.1.1
#   [4f61f5a4] + FFTViews v0.3.2
#   [a2bd30eb] + Graphics v1.1.1
#   [bbac6d45] + IdentityRanges v0.3.1
#   [615f187c] + IfElse v0.1.1
#   [2803e5a7] + ImageAxes v0.6.9
#   [f332f351] + ImageContrastAdjustment v0.3.7
#   [a09fc81d] + ImageCore v0.8.22
#   [51556ac3] + ImageDistances v0.2.13
#   [6a3955dd] + ImageFiltering v0.6.21
#   [82e4d734] + ImageIO v0.5.9
#   [6218d12a] + ImageMagick v1.2.2
#   [bc367c6b] + ImageMetadata v0.9.5
#   [787d08f9] + ImageMorphology v0.2.11
#   [2996bd0c] + ImageQualityIndexes v0.2.2
#   [4e3cecfd] + ImageShow v0.3.1
#   [02fcd773] + ImageTransformations v0.8.13
#   [916415d5] + Images v0.24.1
#   [9b13fd28] + IndirectArrays v0.5.1
#   [d25df0c9] + Inflate v0.1.2
#   [a98d9a8b] + Interpolations v0.13.4
#   [8197267c] + IntervalSets v0.5.3
#   [dbb5928d] + MappedArrays v0.4.1
#   [e94cdb99] + MosaicViews v0.3.3
#   [f09324ee] + Netpbm v1.0.1
#   [52e1d378] + OpenEXR v0.3.2
#   [f57f5aa1] + PNGFiles v0.3.12
#   [5432bcbf] + PaddedViews v0.5.10
#   [d96e819e] + Parameters v0.12.3
#   [eebad327] + PkgVersion v0.1.1
#   [92933f4c] + ProgressMeter v1.7.1
#   [b3c3ace0] + RangeArrays v0.3.2
#   [c84ed2f1] + Ratios v0.4.2
#   [6038ab10] + Rotations v1.0.4
#   [699a6c99] + SimpleTraits v0.9.4
#   [cae243ae] + StackViews v0.1.1
#   [aedffcd0] + Static v0.4.0
#   [62fd8b95] + TensorCore v0.1.1
#   [731e570b] + TiffImages v0.5.2
#   [06e1c1a7] + TiledIteration v0.3.1
#   [3a884ed6] + UnPack v1.0.2
#   [efce3f68] + WoodburyMatrices v0.5.5
#   [c73af94c] + ImageMagick_jll v6.9.10-12+3
#   [905a6f67] + Imath_jll v3.1.2+0
#   [18a262bb] + OpenEXR_jll v3.1.1+0
# Precompiling project...
#   ✓ IfElse
#   ✓ Inflate
#   ✓ MappedArrays
#   ✓ RangeArrays
#   ✓ UnPack
#   ✓ IndirectArrays
#   ✓ TensorCore
#   ✓ PaddedViews
#   ✓ ProgressMeter
#   ✓ Ratios
#   ✓ WoodburyMatrices
#   ✓ CEnum
#   ✓ IdentityRanges
#   ✓ CustomUnitRanges
#   ✓ StackViews
#   ✓ PkgVersion
#   ✓ ComputationalResources
#   ✓ TiledIteration
#   ✓ Parameters
#   ✓ Static
#   ✓ AxisAlgorithms
#   ✓ SimpleTraits
#   ✓ Imath_jll
#   ✓ ImageMagick_jll
#   ✓ Graphics
#   ✓ CatIndices
#   ✓ MosaicViews
#   ✓ FFTViews
#   ✓ CoordinateTransformations
#   ✓ ArrayInterface
#   ✓ OpenEXR_jll
#   ✓ EllipsisNotation
#   ✓ IntervalSets
#   ✓ Rotations
#   ✓ ColorVectorSpace
#   ✓ Interpolations
#   ✓ OpenEXR
#   ✓ AxisArrays
#   ✓ ImageCore
#   ✓ ImageShow
#   ✓ ImageMorphology
#   ✓ Netpbm
#   ✓ ImageAxes
#   ✓ PNGFiles
#   ✓ ImageMagick
#   ✓ ImageTransformations
#   ✓ ImageDistances
#   ✓ ImageMetadata
#   ✓ ImageContrastAdjustment
#   ✓ TiffImages
#   ✓ ImageIO
#   ✓ ImageFiltering
#   ✓ ImageQualityIndexes
#   ✓ Images
#   54 dependencies successfully precompiled in 47 seconds (191 already precompiled, 1 skipped during auto due to previous errors)
#    Resolving package versions...
#    Installed TestImages ────── v1.6.2
#    Installed StringDistances ─ v0.11.1
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [5e47fb64] + TestImages v1.6.2
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [88034a9c] + StringDistances v0.11.1
#   [5e47fb64] + TestImages v1.6.2
# Precompiling project...
#   ✓ StringDistances
#   ✓ TestImages
#   2 dependencies successfully precompiled in 3 seconds (245 already precompiled, 1 skipped during auto due to previous errors)
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [82e4d734] + ImageIO v0.5.9
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`
#    Resolving package versions...
#    Installed VersionParsing ─────── v1.2.1
#    Installed GR_jll ─────────────── v0.62.0+0
#    Installed Mocking ────────────── v0.7.3
#    Installed IrrationalConstants ── v0.1.1
#    Installed PlotUtils ──────────── v1.0.15
#    Installed Tables ─────────────── v1.6.0
#    Installed Latexify ───────────── v0.15.9
#    Installed FileIO ─────────────── v1.11.2
#    Installed Blosc ──────────────── v0.7.1
#    Installed OffsetArrays ───────── v1.10.8
#    Installed LogExpFunctions ────── v0.3.5
#    Installed TimeZones ──────────── v1.6.2
#    Installed SpecialFunctions ───── v1.8.1
#    Installed InverseFunctions ───── v0.1.2
#    Installed LaTeXStrings ───────── v1.3.0
#    Installed InlineStrings ──────── v1.0.1
#    Installed Compat ─────────────── v3.40.0
#    Installed Distances ──────────── v0.10.6
#    Installed ChainRulesCore ─────── v1.11.1
#    Installed DoubleFloats ───────── v1.1.24
#    Installed StatsBase ──────────── v0.33.12
#    Installed ChangesOfVariables ─── v0.1.1
#    Installed Parsers ────────────── v2.1.2
#    Installed GenericLinearAlgebra ─ v0.2.7
#    Installed SentinelArrays ─────── v1.3.8
#    Installed HTTP ───────────────── v0.9.16
#    Installed StaticArrays ───────── v1.2.13
#    Installed MacroTools ─────────── v0.5.9
#    Installed WeakRefStrings ─────── v1.4.1
#    Installed Mustache ───────────── v1.0.12
#    Installed FilePathsBase ──────── v0.9.14
#    Installed DocStringExtensions ── v0.8.6
#    Installed HDF5 ───────────────── v0.15.7
#    Installed ColorSchemes ───────── v3.15.0
#    Installed PrettyTables ───────── v1.2.3
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [dca85d43] + QuartzImageIO v0.7.3
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [a74b3585] ↑ Blosc v0.7.0 ⇒ v0.7.1
#   [d360d2e6] ↑ ChainRulesCore v1.4.0 ⇒ v1.11.1
#   [9e997f8a] + ChangesOfVariables v0.1.1
#   [35d6a980] ↑ ColorSchemes v3.14.0 ⇒ v3.15.0
#   [3da002f7] ↓ ColorTypes v0.11.0 ⇒ v0.10.12
#   [c3611d14] ↓ ColorVectorSpace v0.9.7 ⇒ v0.8.7
#   [34da2185] ↑ Compat v3.37.0 ⇒ v3.40.0
#   [b4f34e82] ↑ Distances v0.10.4 ⇒ v0.10.6
#   [ffbed154] ↑ DocStringExtensions v0.8.5 ⇒ v0.8.6
#   [497a8b3b] ↑ DoubleFloats v1.1.23 ⇒ v1.1.24
#   [5789e2e9] ↑ FileIO v1.11.1 ⇒ v1.11.2
#   [48062228] ↑ FilePathsBase v0.9.11 ⇒ v0.9.14
#   [14197337] ↑ GenericLinearAlgebra v0.2.6 ⇒ v0.2.7
#   [f67ccb44] ↑ HDF5 v0.15.6 ⇒ v0.15.7
#   [cd3eb016] ↑ HTTP v0.9.14 ⇒ v0.9.16
#   [842dd82b] + InlineStrings v1.0.1
#   [3587e190] + InverseFunctions v0.1.2
#   [92d709cd] ↑ IrrationalConstants v0.1.0 ⇒ v0.1.1
#   [b964fa9f] ↑ LaTeXStrings v1.2.1 ⇒ v1.3.0
#   [23fbe1c1] ↑ Latexify v0.15.6 ⇒ v0.15.9
#   [2ab3a3ac] ↑ LogExpFunctions v0.3.3 ⇒ v0.3.5
#   [1914dd2f] ↑ MacroTools v0.5.8 ⇒ v0.5.9
#   [78c3b35d] ↑ Mocking v0.7.2 ⇒ v0.7.3
#   [ffc61752] ↑ Mustache v1.0.10 ⇒ v1.0.12
#   [6fe1bfb0] ↑ OffsetArrays v1.10.7 ⇒ v1.10.8
#   [69de0a69] ↑ Parsers v2.0.3 ⇒ v2.1.2
#   [995b91a9] ↑ PlotUtils v1.0.14 ⇒ v1.0.15
#   [08abe8d2] ↑ PrettyTables v1.1.0 ⇒ v1.2.3
#   [dca85d43] + QuartzImageIO v0.7.3
#   [91c51154] ↑ SentinelArrays v1.3.7 ⇒ v1.3.8
#   [276daf66] ↑ SpecialFunctions v1.6.1 ⇒ v1.8.1
#   [90137ffa] ↑ StaticArrays v1.2.12 ⇒ v1.2.13
#   [2913bbd2] ↑ StatsBase v0.33.10 ⇒ v0.33.12
#   [bd369af6] ↑ Tables v1.5.2 ⇒ v1.6.0
#   [62fd8b95] - TensorCore v0.1.1
#   [f269a46b] ↑ TimeZones v1.5.7 ⇒ v1.6.2
#   [81def892] ↑ VersionParsing v1.2.0 ⇒ v1.2.1
#   [ea10d353] ↑ WeakRefStrings v1.3.0 ⇒ v1.4.1
#   [d2c73de3] ↑ GR_jll v0.59.0+0 ⇒ v0.62.0+0
#   [05823500] + OpenLibm_jll
#     Building TimeZones → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/8de32288505b7db196f36d27d7236464ef50dba1/build.log`
#     Building HDF5 ─────→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/698c099c6613d7b7f151832868728f426abe698b/build.log`
# Precompiling project...
#   ✓ VersionParsing
#   ✓ LaTeXStrings
#   ✓ InverseFunctions
#   ✓ OpenLibm_jll
#   ✓ DocStringExtensions
#   ✓ IrrationalConstants
#   ✓ OffsetArrays
#   ✓ ChangesOfVariables
#   ✓ GenericLinearAlgebra
#   ✓ SentinelArrays
#   ✓ FilePathsBase
#   ✓ InlineStrings
#   ✓ Distances
#   ✓ ChainRulesCore
#   ✓ MacroTools
#   ✓ Blosc
#   ✓ Tables
#   ✓ CatIndices
#   ✓ FileIO
#   ✓ PaddedViews
#   ✓ IdentityRanges
#   ✓ GR_jll
#   ✓ HTTP
#   ✓ StackViews
#   ✓ Conda
#   ✓ TiledIteration
#   ✓ StringDistances
#   ✓ Hiccup
#   ✓ WeakRefStrings
#   ✓ SimpleTraits
#   ✓ LogExpFunctions
#   ✓ Latexify
#   ✓ Mustache
#   ✓ Lazy
#   ✓ WebSockets
#   ✓ PlotlyBase
#   ✓ HDF5
#   ✓ MosaicViews
#   ✓ TimeZones
#   ✓ StaticArrays
#   ✓ GR
#   ✓ IJulia
#   ✓ JLD
#   ✓ StructArrays
#   ✓ Mux
#   ✓ Intervals
#   ✓ SpecialFunctions
#   ✓ CSV
#   ✓ PrettyTables
#   ✓ StatsBase
#   ✓ ColorTypes
#   ✓ Contour
#   ✓ CoordinateTransformations
#   ✓ Rotations
#   ✓ NearestNeighbors
#   ✓ Polynomials
#   ✓ Interpolations
#   ✓ Clustering
#   ✓ Colors
#   ✓ DoubleFloats
#   ✓ Graphics
#   ✓ Widgets
#   ✓ OpenEXR
#   ✓ DSP
#   ✓ GeometryBasics
#   ✓ TestImages
#   ✓ ColorVectorSpace
#   ✓ ImageCore
#   ✗ PolynomialMatrices
#   ✓ WebIO
#   ✓ ColorSchemes
#   ✓ TextParse
#   ✓ ImageShow
#   ✓ ImageMorphology
#   ✓ ImageAxes
#   ✓ PNGFiles
#   ✓ Netpbm
#   ✓ ImageMagick
#   ✓ QuartzImageIO
#   ✓ ImageTransformations
#   ✓ CSVFiles
#   ✓ ImageDistances
#   ✓ ImageMetadata
#   ✓ JSExpr
#   ✓ TiffImages
#   ✓ ImageIO
#   ✓ ImageContrastAdjustment
#   ✓ PlotUtils
#   ✓ Blink
#   ✓ RecipesPipeline
#   ✓ PlotThemes
#   ✓ ImageFiltering
#   ✓ DataFrames
#   ✓ PlotlyJS
#   ✓ ImageQualityIndexes
#   ✓ Images
#   ✓ Plotly
#   ✓ Plots
#   97 dependencies successfully precompiled in 115 seconds (154 already precompiled)
#   3 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#   1 dependency errored. To see a full report either run `import Pkg; Pkg.precompile()` or load the package
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [6218d12a] + ImageMagick v1.2.2
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`
# Precompiling project...
#   ✓ InlineStrings
#   ✓ AssetRegistry
#   ✓ TableShowUtils
#   ✓ Conda
#   ✓ WeakRefStrings
#   ✓ IJulia
#   ✓ Mux
#   ✓ PlotlyBase
#   ✓ WebIO
#   ✓ TimeZones
#   ✓ CSV
#   ✓ Intervals
#   ✓ JSExpr
#   ✓ Polynomials
#   ✓ Blink
#   ✓ DoubleFloats
#   ✓ DSP
#   ✗ PolynomialMatrices
#   ✓ TextParse
#   ✓ CSVFiles
#   ✓ PlotlyJS
#   ✓ Plotly
#   ✓ Plots
#   22 dependencies successfully precompiled in 46 seconds (229 already precompiled)
#   2 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#   1 dependency errored. To see a full report either run `import Pkg; Pkg.precompile()` or load the package
#    Resolving package versions...
#    Installed gdk_pixbuf_jll ─── v2.42.6+0
#    Installed ATK_jll ────────── v2.36.1+0
#    Installed GTK3_jll ───────── v3.24.30+0
#    Installed Libepoxy_jll ───── v1.5.8+0
#    Installed RoundingIntegers ─ v1.0.0
#    Installed Pango_jll ──────── v1.47.0+0
#    Installed GtkReactive ────── v1.0.6
#    Installed ImageView ──────── v0.10.14
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [86fae568] + ImageView v0.10.14
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [159f3aea] + Cairo v1.0.5
#   [4c0ca9eb] + Gtk v1.1.9
#   [27996c0f] + GtkReactive v1.0.6
#   [86fae568] + ImageView v0.10.14
#   [a223df75] + Reactive v0.8.3
#   [d5f540fe] + RoundingIntegers v1.0.0
#   [7b86fcea] + ATK_jll v2.36.1+0
#   [ee1fde0b] + Dbus_jll v1.12.16+3
#   [77ec8976] + GTK3_jll v3.24.30+0
#   [42c93a91] + Libepoxy_jll v1.5.8+0
#   [36c8627f] + Pango_jll v1.47.0+0
#   [3c9796d7] + Xorg_libXcomposite_jll v0.4.5+4
#   [0aeada51] + Xorg_libXdamage_jll v1.1.5+4
#   [b6f176f1] + Xorg_libXtst_jll v1.2.3+4
#   [b437f822] + adwaita_icon_theme_jll v3.33.92+5
#   [de012916] + at_spi2_atk_jll v2.34.1+4
#   [0fc3237b] + at_spi2_core_jll v2.34.0+4
#   [da03df04] + gdk_pixbuf_jll v2.42.6+0
#   [059c91fe] + hicolor_icon_theme_jll v0.17.0+3
#   [bf975903] + iso_codes_jll v4.3.0+4
# Precompiling project...
#   ✓ hicolor_icon_theme_jll
#   ✓ RoundingIntegers
#   ✓ iso_codes_jll
#   ✓ InlineStrings
#   ✓ AssetRegistry
#   ✓ TableShowUtils
#   ✓ Conda
#   ✓ Reactive
#   ✓ Dbus_jll
#   ✓ ATK_jll
#   ✓ Xorg_libXdamage_jll
#   ✓ Xorg_libXcomposite_jll
#   ✓ Xorg_libXtst_jll
#   ✓ Libepoxy_jll
#   ✓ gdk_pixbuf_jll
#   ✓ adwaita_icon_theme_jll
#   ✓ Pango_jll
#   ✓ at_spi2_core_jll
#   ✓ WeakRefStrings
#   ✓ IJulia
#   ✓ Cairo
#   ✓ at_spi2_atk_jll
#   ✓ PlotlyBase
#   ✓ Mux
#   ✓ GTK3_jll
#   ✓ WebIO
#   ✓ TimeZones
#   ✓ CSV
#   ✓ Intervals
#   ✓ JSExpr
#   ✓ Polynomials
#   ✓ Blink
#   ✓ DoubleFloats
#   ✓ Gtk
#   ✓ DSP
#   ✗ PolynomialMatrices
#   ✓ TextParse
#   ✓ CSVFiles
#   ✓ GtkReactive
#   ✓ PlotlyJS
#   ✓ Plotly
#   ✓ Plots
#   ✓ ImageView
#   42 dependencies successfully precompiled in 123 seconds (229 already precompiled)
#   2 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#   1 dependency errored. To see a full report either run `import Pkg; Pkg.precompile()` or load the package

# %%
function cbf(n,k,t)
  if k==0
    return 1/sqrt(n)
  else
    return sqrt(2/n)*cos(k*(2t+1)*pi/(2n))
  end
end

function dctcomp(B,l)
  m,n=size(B)
  a=Int(floor(m/8))
  b=Int(floor(n/8))
  
  C=[cbf(8,i,j) for i=0:7, j=0:7]
  
  Mask=[i+j<l for i=1:8, j=1:8]
  
  M=zeros(m,n)
  for i=1:a, j=1:b
    rows=(8i-7):8i
    cols=(8j-7):8j
    X=B[rows,cols]
    Y=C*X*C'
    Y2=Y.*Mask
    X2=C'*Y2*C
    M[rows,cols]=X2
  end
  
    println("Space saved: ", 100(1-sum(Mask)/64), "%")
    println("Average error: ", norm(B-M)/(m*n))
  
  return M
  

  
end
# Out:
# dctcomp (generic function with 1 method)

# %%
using Images, TestImages, ImageView, LinearAlgebra

img=testimage("cameraman")

A=channelview(img) #image to matrix
n,m=size(A)
O=ones(n,m)

B=255*A-127*O

l=6
C=dctcomp(B,l)
D=(C+127*O)/255

img2=colorview(Gray,D) #matrix to image

E=abs.(A-D) #error matrix
img3=colorview(Gray,E)

mosaicview(img, img2, img3, nrow=1)
# Out:
#  Downloading artifact: images
# Space saved: 84.375%
# Average error: 0.010954267511216774
# 512×1536 MosaicView{Gray{Float64}, 4, Base.ReshapedArray{Gray{Float64}, 4, PaddedView{Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{Gray{Float64}, 3, 3, Tuple{OffsetArrays.OffsetMatrix{Gray{N0f8}, PaddedView{Gray{N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{Gray{N0f8}}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Base.ReinterpretArray{Gray{Float64}, 2, Float64, Matrix{Float64}, true}}}, OffsetArrays.OffsetMatrix{Gray{Float64}, PaddedView{Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Base.ReinterpretArray{Gray{Float64}, 2, Float64, Matrix{Float64}, true}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.611765)  …  Gray{Float64}(0.0034909)
#  Gray{Float64}(0.611765)     Gray{Float64}(0.000391488)
#  Gray{Float64}(0.619608)     Gray{Float64}(0.00232676)
#  Gray{Float64}(0.627451)     Gray{Float64}(0.0019334)
#  Gray{Float64}(0.619608)     Gray{Float64}(0.000295589)
#  Gray{Float64}(0.611765)  …  Gray{Float64}(0.0047089)
#  Gray{Float64}(0.619608)     Gray{Float64}(0.00212979)
#  Gray{Float64}(0.627451)     Gray{Float64}(0.000871232)
#  Gray{Float64}(0.619608)     Gray{Float64}(9.74139e-5)
#  Gray{Float64}(0.611765)     Gray{Float64}(0.00283207)
#  Gray{Float64}(0.607843)  …  Gray{Float64}(0.00412376)
#  Gray{Float64}(0.607843)     Gray{Float64}(0.00191713)
#  Gray{Float64}(0.607843)     Gray{Float64}(0.00751377)
#  ⋮                        ⋱  ⋮
#  Gray{Float64}(0.509804)  …  Gray{Float64}(0.0495509)
#  Gray{Float64}(0.443137)     Gray{Float64}(0.0504193)
#  Gray{Float64}(0.396078)     Gray{Float64}(0.000691312)
#  Gray{Float64}(0.384314)     Gray{Float64}(0.0435162)
#  Gray{Float64}(0.435294)     Gray{Float64}(0.00717948)
#  Gray{Float64}(0.494118)  …  Gray{Float64}(0.0138216)
#  Gray{Float64}(0.47451)      Gray{Float64}(0.00159975)
#  Gray{Float64}(0.447059)     Gray{Float64}(0.0063872)
#  Gray{Float64}(0.454902)     Gray{Float64}(0.00861848)
#  Gray{Float64}(0.47451)      Gray{Float64}(0.0210198)
#  Gray{Float64}(0.47451)   …  Gray{Float64}(0.00677169)
#  Gray{Float64}(0.47451)      Gray{Float64}(0.00994048)

# %%
img4=load("lion.jpg")
# Out:
# 1080×1920 Array{RGBX{N0f8},2} with eltype RGBX{N0f8}:
#  RGBX{N0f8}(0.0,0.0,0.0)        …  RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.0,0.0,0.0)           RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.0,0.0,0.0)           RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.0,0.0,0.0)           RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.0,0.0,0.0)           RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.008,0.008,0.008)  …  RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.016,0.016,0.016)     RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.024,0.024,0.024)     RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.02,0.02,0.02)        RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.012,0.012,0.012)     RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.004,0.004,0.004)  …  RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.0,0.0,0.0)           RGBX{N0f8}(0.004,0.004,0.004)
#  RGBX{N0f8}(0.0,0.0,0.0)           RGBX{N0f8}(0.004,0.004,0.004)
#  ⋮                              ⋱
#  RGBX{N0f8}(0.059,0.059,0.059)     RGBX{N0f8}(0.027,0.027,0.027)
#  RGBX{N0f8}(0.063,0.063,0.063)     RGBX{N0f8}(0.027,0.027,0.027)
#  RGBX{N0f8}(0.075,0.075,0.075)  …  RGBX{N0f8}(0.027,0.027,0.027)
#  RGBX{N0f8}(0.078,0.078,0.078)     RGBX{N0f8}(0.027,0.027,0.027)
#  RGBX{N0f8}(0.078,0.078,0.078)     RGBX{N0f8}(0.031,0.031,0.031)
#  RGBX{N0f8}(0.078,0.078,0.078)     RGBX{N0f8}(0.031,0.031,0.031)
#  RGBX{N0f8}(0.075,0.075,0.075)     RGBX{N0f8}(0.031,0.031,0.031)
#  RGBX{N0f8}(0.071,0.071,0.071)  …  RGBX{N0f8}(0.031,0.031,0.031)
#  RGBX{N0f8}(0.059,0.059,0.059)     RGBX{N0f8}(0.031,0.031,0.031)
#  RGBX{N0f8}(0.055,0.055,0.055)     RGBX{N0f8}(0.031,0.031,0.031)
#  RGBX{N0f8}(0.067,0.067,0.067)     RGBX{N0f8}(0.031,0.031,0.031)
#  RGBX{N0f8}(0.078,0.078,0.078)     RGBX{N0f8}(0.031,0.031,0.031)

# %%
img5=load("colors.jpg")

A=channelview(img5)

Z=zeros(144,344)
B=copy(A)
B[2,:,:]=Z
B[3,:,:]=Z

colorview(RGB,B)
# Out:
# 144×344 mappedarray(MappedArrays.var"#7#9"{RGB{N0f8}}(), MappedArrays.var"#8#10"{RGBX{N0f8}}(), ::Array{RGBX{N0f8},2}) with eltype RGB{N0f8}:
#  RGB{N0f8}(0.98,0.98,0.988)    …  RGB{N0f8}(0.98,0.98,0.988)
#  RGB{N0f8}(0.98,0.98,0.988)       RGB{N0f8}(0.98,0.98,0.988)
#  RGB{N0f8}(0.98,0.98,0.988)       RGB{N0f8}(0.98,0.98,0.988)
#  RGB{N0f8}(0.98,0.98,0.988)       RGB{N0f8}(0.98,0.98,0.988)
#  RGB{N0f8}(0.98,0.98,0.988)       RGB{N0f8}(0.98,0.98,0.988)
#  RGB{N0f8}(0.98,0.98,0.988)    …  RGB{N0f8}(0.98,0.98,0.988)
#  RGB{N0f8}(0.98,0.98,0.988)       RGB{N0f8}(0.98,0.98,0.988)
#  RGB{N0f8}(0.98,0.98,0.988)       RGB{N0f8}(0.98,0.98,0.988)
#  RGB{N0f8}(0.98,0.98,0.988)       RGB{N0f8}(0.965,0.961,0.98)
#  RGB{N0f8}(0.98,0.98,0.988)       RGB{N0f8}(0.949,0.973,0.957)
#  RGB{N0f8}(0.98,0.98,0.988)    …  RGB{N0f8}(0.961,0.988,0.961)
#  RGB{N0f8}(0.98,0.98,0.988)       RGB{N0f8}(0.996,0.988,1.0)
#  RGB{N0f8}(0.98,0.98,0.988)       RGB{N0f8}(1.0,0.973,1.0)
#  ⋮                             ⋱
#  RGB{N0f8}(0.961,0.976,0.988)     RGB{N0f8}(0.631,0.486,0.757)
#  RGB{N0f8}(0.969,0.961,0.973)     RGB{N0f8}(1.0,0.855,0.953)
#  RGB{N0f8}(0.961,0.937,0.937)     RGB{N0f8}(0.933,0.988,0.78)
#  RGB{N0f8}(1.0,0.984,0.973)    …  RGB{N0f8}(1.0,0.961,0.984)
#  RGB{N0f8}(1.0,0.941,1.0)         RGB{N0f8}(0.714,0.953,0.894)
#  RGB{N0f8}(1.0,0.953,0.992)       RGB{N0f8}(0.98,0.965,0.961)
#  RGB{N0f8}(0.929,0.922,0.941)     RGB{N0f8}(1.0,0.859,0.91)
#  RGB{N0f8}(0.992,0.996,1.0)       RGB{N0f8}(0.894,0.737,0.871)
#  RGB{N0f8}(0.996,0.996,1.0)    …  RGB{N0f8}(0.961,0.867,1.0)
#  RGB{N0f8}(0.98,0.976,0.996)      RGB{N0f8}(0.949,0.753,1.0)
#  RGB{N0f8}(0.949,0.953,0.973)     RGB{N0f8}(0.949,0.765,0.906)
#  RGB{N0f8}(0.925,0.945,0.969)     RGB{N0f8}(1.0,0.945,0.973)
